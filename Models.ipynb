# %% [markdown]
# # Spotify Popularity Prediction Part 3

# %% [markdown]
# ## Spark Session

# %%
from pyspark.sql import SparkSession

# Initialize Spark session with enough memory for the 189GB dataset
# 7 executors x 25g = 175g total executor memory across the cluster

spark = (
    SparkSession.builder
    .appName("Spotify_Part3_RF")
    .config("spark.driver.memory", "10g")
    .config("spark.executor.instances", "7")
    .config("spark.executor.memory", "25g")
    .config("spark.executor.memoryOverhead", "4g") 
    .config("spark.sql.shuffle.partitions", "100")  #reduced from 200 for sample
    .getOrCreate()
)

# %% [markdown]
# ## Load Parquet Tables

# %%
from pyspark.sql import functions as F

data_path = "/expanse/lustre/projects/uci157/darenas/shared/spotify_clean_parquet"

# Load all tables
tracks = spark.read.parquet(data_path + "/tracks.parquet")
artists = spark.read.parquet(data_path + "/artists.parquet")
albums = spark.read.parquet(data_path + "/albums.parquet")
track_artists = spark.read.parquet(data_path + "/track_artists.parquet")

# Audio features
audio = spark.read.parquet("/expanse/lustre/projects/uci157/darenas/shared/spotify_clean_audio_features_parquet")

print("Data loaded")
# Out:
# Data loaded

# %% [markdown]
# ## Cleaning

# %%
# Audio features cleaning
# Rename duration_ms to avoid confusion with tracks.duration_ms
audio = audio.withColumnRenamed("duration_ms", "audio_duration_ms")

# Drop rows with null response
audio = audio.filter(F.col("null_response").isNull())

# Cast all audio feature columns to double for ML compatibility
audio_cols = [
    "audio_duration_ms", "time_signature", "tempo",
    "key", "mode", "danceability", "energy",
    "loudness", "speechiness", "acousticness",
    "instrumentalness", "liveness", "valence"
]
for c in audio_cols:
    audio = audio.withColumn(c, F.col(c).cast("double"))

# %%
# Artist deduplication
# Some artists appear multiple times (ex. BTS has different entries for each member)
# Keep only the row with the highest followers_total per artist name

from pyspark.sql.window import Window

artists_clean = artists.select(
    F.col("rowid").alias("artist_rowid"),
    F.col("id"),
    F.col("name"),
    F.col("followers_total"),
    F.col("popularity").alias("artist_popularity")
)

# Window: for each artist name, rank by followers descending
w = Window.partitionBy("name").orderBy(
    F.desc("followers_total"),
    F.desc("artist_popularity")
)
artists_clean = (
    artists_clean
    .withColumn("rank", F.row_number().over(w))
    .filter(F.col("rank") == 1)  # keep only the top row per artist name
    .drop("rank")
)

# %%
# Only take cols we need from each

# Tracks
tracks_clean = tracks.select(
    F.col("rowid").alias("track_rowid"),
    F.col("id").alias("track_id"),
    F.col("name").alias("track_name"),
    F.col("popularity"),           # this is our prediction target
    F.col("duration_ms").alias("track_duration"),
    F.col("explicit"),
    F.col("album_rowid")
)

# Sample before joins
# Sampling on tracks first = all 4 joins run on 1.25M rows instead of 256M
# Prevents shuffle files from filling up the executor local disk to prevent spill error
tracks_clean = tracks_clean.sample(False, 0.005, seed=42)

# Albums
albums_clean = albums.select(
    F.col("rowid").alias("album_rowid"),
    F.col("popularity").alias("album_popularity"),
    "label",
    "total_tracks"
)

# %% [markdown]
# ## Join Pipeline

# %%
# Join tracks to audio features, track_artists bridge table, artists, and albums
# All joins are left so we keep tracks even if audio/artist/album data is missing

main_df = (
    tracks_clean
    # Join audio features on track_id
    .join(audio, tracks_clean.track_id == audio.track_id, "left")
    .drop(audio["track_id"])                          # drop duplicate track_id from audio
    # Join bridge table to get artist_rowid per track
    .join(track_artists, tracks_clean.track_rowid == track_artists.track_rowid, "left")
    .drop(track_artists["track_rowid"])               # drop duplicate track_rowid
    # Join artists on artist_rowid
    .join(artists_clean, track_artists.artist_rowid == artists_clean.artist_rowid, "left")
    .drop(track_artists["artist_rowid"]).drop(artists_clean["artist_rowid"])
    # Join albums on album_rowid
    .join(albums_clean, tracks_clean.album_rowid == albums_clean.album_rowid, "left")
    .drop(albums_clean["album_rowid"])                # drop duplicate album_rowid
)

# %%
# Deduplicate tracks
# A track with multiple artists creates multiple rows after the join
# To fix this collapse to one row per track_id using agg

df_clean = main_df.groupBy("track_id").agg(
    F.first("track_name").alias("track_name"),
    F.first("name").alias("artist_name"),             # primary artist name
    F.first("popularity").alias("popularity"),         # track popularity (our target)
    F.max("followers_total").alias("followers_total"), # take the most-followed artist
    F.max("artist_popularity").alias("artist_popularity"),
    F.first("album_popularity").alias("album_popularity"),
    F.first("total_tracks").alias("total_tracks"),
    F.first("track_duration").alias("track_duration"),
    F.first("explicit").alias("explicit"),
    *[F.first(c).alias(c) for c in audio_cols]        # all audio features
)

# Drop rows missing the target or track id
df_clean = df_clean.na.drop(subset=["popularity", "track_id"])

# %% [markdown]
# ## Preprocessing

# %%
# Feature engineering
# log1p(followers) compresses the huge range of follower counts (0 to 80M+)

df_clean = df_clean.withColumn("log_followers", F.log1p(F.col("followers_total")))

# Interaction feature: energy * danceability captures "hype" tracks
df_clean = df_clean.withColumn("energy_dance", F.col("energy") * F.col("danceability"))

# %%
# Imputer for missing values

from pyspark.ml.feature import Imputer
from pyspark.sql import Row

toy_data = spark.createDataFrame([
    Row(followers_total=1000.0,     tempo=120.0, danceability=None, energy=0.80),
    Row(followers_total=None,       tempo=130.0, danceability=0.65, energy=None),
    Row(followers_total=500000.0,   tempo=None,  danceability=0.55, energy=0.70),
    Row(followers_total=78000000.0, tempo=110.0, danceability=0.75, energy=0.90),
])

demo_cols = ["followers_total", "tempo", "danceability", "energy"]
imputer_demo = Imputer(
    inputCols=demo_cols,
    outputCols=[c + "_imp" for c in demo_cols]
).setStrategy("mean")  # replace nulls with column mean

imputer_demo.fit(toy_data).transform(toy_data).show(truncate=False)
# Out:
# +---------------+-----+------------+------+-------------------+---------+----------------+------------------+
# |followers_total|tempo|danceability|energy|followers_total_imp|tempo_imp|danceability_imp|energy_imp        |
# +---------------+-----+------------+------+-------------------+---------+----------------+------------------+
# |1000.0         |120.0|NULL        |0.8   |1000.0             |120.0    |0.65            |0.8               |
# |NULL           |130.0|0.65        |NULL  |2.6167E7           |130.0    |0.65            |0.7999999999999999|
# |500000.0       |NULL |0.55        |0.7   |500000.0           |120.0    |0.55            |0.7               |
# |7.8E7          |110.0|0.75        |0.9   |7.8E7              |110.0    |0.75            |0.9               |
# +---------------+-----+------------+------+-------------------+---------+----------------+------------------+

# %%
# Handle missing values on real data
# Fill nulls with 0 for all numeric feature columns
# missing audio features = track has no audio data, fill as 0

numeric_cols_full = [
    "followers_total", "artist_popularity", "album_popularity", "total_tracks",
    "track_duration", "explicit", "log_followers", "energy_dance"
] + audio_cols

df_clean = df_clean.fillna(0, subset=numeric_cols_full)

# %%
from pyspark.ml.feature import VectorAssembler, Normalizer

# All numeric features 
feature_cols = [
    "followers_total", "artist_popularity", "album_popularity", "total_tracks",
    "track_duration", "explicit", "log_followers", "energy_dance"
] + audio_cols

# VectorAssembler combines all feature columns into a single vector column
assembler = VectorAssembler(
    inputCols=feature_cols,
    outputCol="features_raw",
    handleInvalid="keep"  # keep rows with remaining nulls rather than dropping
)

# Normalizer scales each row's feature vector to unit norm (L2)
normalizer = Normalizer(inputCol="features_raw", outputCol="features", p=2)

# Apply assembler and normalizer
df_assembled = assembler.transform(df_clean)
df_final = normalizer.transform(df_assembled).select(
    "track_id", "track_name", "artist_name", "popularity", "features"
)

# Cache so train/val/test splits don't recompute the full join and clean process
df_final = df_final.cache()
row_count = df_final.count()  # triggers caching
print(f"Preprocessed rows: {row_count:,}")
df_final.show(5, truncate=True)
# Out:
# Preprocessed rows: 1,278,282
# +--------------------+--------------------+--------------------+----------+--------------------+
# |            track_id|          track_name|         artist_name|popularity|            features|
# +--------------------+--------------------+--------------------+----------+--------------------+
# |0000RM7QYBRAsuFAQ...|             Mo n Me|           Modd Jobs|         0|(21,[0,3,4,6],[5....|
# |0001qtVaca5vVqHv0...|               Arena|         Kronnospace|         0|(21,[0,1,3,4,6],[...|
# |000BJtGc0SLMN5ixU...|   Trịnh Vương Maria|          Thanh Hoài|         0|(21,[0,1,2,3,4,6]...|
# |000Wdim8xmdzFdAds...|Emotional Intelli...|Wave Particle Sin...|         0|(21,[0,1,3,4,6],[...|
# |000XiFdhd8fypmIvU...|       Escaped Pulse|      Spiritual Yoga|         0|(21,[0,1,3,4,6],[...|
# +--------------------+--------------------+--------------------+----------+--------------------+
# only showing top 5 rows

# %% [markdown]
# ## Train / Validation / Test Split

# %%
# 70% train, 15% validation, 15% test

train_df, val_df, test_df = df_final.randomSplit([0.7, 0.15, 0.15], seed=42)

print(f"Train:      {train_df.count():,}")
print(f"Validation: {val_df.count():,}")
print(f"Test:       {test_df.count():,}")
# Out:
# Train:      895,418
# Validation: 191,376
# Test:       191,488

# %% [markdown]
# ## Distributed Random Forest: Model 1

# %%
from pyspark.ml.regression import RandomForestRegressor

# Model 1: starting point for hyperparameters 
# Using regression since popularity is a continuous 0-100 score

rf = RandomForestRegressor(
    labelCol="popularity",
    featuresCol="features",
    numTrees=50,    
    maxDepth=8,  
    featureSubsetStrategy="auto",
    seed=42
)

import time

start_time = time.time()   

rf_model = rf.fit(train_df)

end_time = time.time()     

print("Fitting Model 1 (numTrees=50, maxDepth=8)")

print("Training time (seconds):", end_time - start_time)
print("Training time (minutes):", (end_time - start_time)/60)

print("Done")
# Out:
# Fitting Model 1 (numTrees=50, maxDepth=8)
# Training time (seconds): 15.709596872329712
# Training time (minutes): 0.26182661453882855
# Done

# %% [markdown]
# ## Evaluation (Train vs Validation vs Test)

# %%
from pyspark.ml.evaluation import RegressionEvaluator

eval_rmse = RegressionEvaluator(labelCol="popularity", predictionCol="prediction", metricName="rmse")
eval_r2   = RegressionEvaluator(labelCol="popularity", predictionCol="prediction", metricName="r2")

# Predict on all 3 splits
pred_train = rf_model.transform(train_df)
pred_val   = rf_model.transform(val_df)
pred_test  = rf_model.transform(test_df)

print("Model 1: numTrees=50, maxDepth=8")
print(f"RMSE  train={eval_rmse.evaluate(pred_train):.3f}  val={eval_rmse.evaluate(pred_val):.3f}  test={eval_rmse.evaluate(pred_test):.3f}")
print(f"R2    train={eval_r2.evaluate(pred_train):.3f}    val={eval_r2.evaluate(pred_val):.3f}    test={eval_r2.evaluate(pred_test):.3f}")
# Out:
# Model 1: numTrees=50, maxDepth=8
# RMSE  train=2.709  val=2.757  test=2.722
# R2    train=0.708    val=0.707    test=0.708

# %%
cols_to_show = ["track_name", "artist_name", "popularity", "prediction"]

print("Train examples")
pred_train.select(*cols_to_show)\
    .filter(F.col("track_name") != "")\
    .filter(F.col("popularity") > 0)\
    .orderBy(F.desc("popularity"))\
    .show(10, truncate=False)

print("Validation examples")
pred_val.select(*cols_to_show)\
    .filter(F.col("track_name") != "")\
    .filter(F.col("popularity") > 0)\
    .orderBy(F.desc("popularity"))\
    .show(10, truncate=False)

print("Test examples")
pred_test.select(*cols_to_show)\
    .filter(F.col("track_name") != "")\
    .filter(F.col("popularity") > 0)\
    .orderBy(F.desc("popularity"))\
    .show(10, truncate=False)
# Out:
# Train examples
# +----------------------+---------------+----------+------------------+
# |track_name            |artist_name    |popularity|prediction        |
# +----------------------+---------------+----------+------------------+
# |Pink Pony Club        |Chappell Roan  |87        |23.91461171554553 |
# |LOVE. FEAT. ZACARI.   |Zacari         |85        |16.912389610866533|
# |Atlantis              |Seafret        |84        |31.684222660225995|
# |Chasing Cars          |Snow Patrol    |83        |22.174647397323096|
# |Hey Brother           |Avicii         |81        |16.912389610866533|
# |Where Is The Love?    |Black Eyed Peas|81        |24.502895552123164|
# |Cantada Boba - Ao Vivo|Jorge & Mateus |80        |16.912389610866533|
# |Somebody (2024)       |Sante Sansone  |78        |30.727481702739098|
# |White Flag            |Dido           |78        |26.528025617479763|
# |that way              |Tate McRae     |77        |23.91461171554553 |
# +----------------------+---------------+----------+------------------+
# only showing top 10 rows
#
# Validation examples
# +-------------------------------------------------------------+---------------+----------+------------------+
# |track_name                                                   |artist_name    |popularity|prediction        |
# +-------------------------------------------------------------+---------------+----------+------------------+
# |Smile                                                        |Morgan Wallen  |83        |23.029893123381044|
# |CATFISH                                                      |Doechii        |81        |27.883802521746585|
# |Fluorescent Adolescent                                       |Arctic Monkeys |78        |16.912389610866533|
# |Dein Mann Freestyle                                          |benno!         |73        |28.342502759854682|
# |YEDA YUNG                                                    |YUNG DSA       |73        |28.342055412365376|
# |Chica Ideal                                                  |Sebastian Yatra|71        |16.912389610866533|
# |Ô Queiroz - Live At HSBC Arena/Rio de Janeiro(RJ)-Brazil/2012|Grupo Revelação|70        |26.022767235260662|
# |I Knew You Were Trouble (Taylor's Version)                   |Taylor Swift   |70        |17.55461021982791 |
# |DONA DE MIM                                                  |Ana Castela    |70        |22.548428023393285|
# |BABY                                                         |GIMS           |69        |23.91461171554553 |
# +-------------------------------------------------------------+---------------+----------+------------------+
# only showing top 10 rows
#
# Test examples
# +-----------------------------------------------------+--------------------+----------+------------------+
# |track_name                                           |artist_name         |popularity|prediction        |
# +-----------------------------------------------------+--------------------+----------+------------------+
# |Grenade                                              |Bruno Mars          |82        |17.29442427148871 |
# |MIENTRAS ME CURO DEL CORA                            |KAROL G             |78        |16.912389610866533|
# |Running Wild                                         |Jin                 |78        |22.548428023393285|
# |River                                                |Leon Bridges        |77        |24.041889906248997|
# |Intro                                                |The xx              |72        |25.307491504778664|
# |Radio/Video                                          |System Of A Down    |71        |23.029893123381044|
# |Oh Ana                                               |Mother Mother       |70        |25.919732468963794|
# |Take Two                                             |BTS                 |69        |16.170899281407145|
# |Rain Sounds for Sleeping, Pt. 30 (Continuous No Gaps)|White Noise Radiance|68        |15.657382734382798|
# |LA NETA                                              |Calle 24            |68        |27.883802521746585|
# +-----------------------------------------------------+--------------------+----------+------------------+
# only showing top 10 rows

# %% [markdown]
# ## Hyperparameter Comparison: Model 2

# %%
# Model 2: deeper trees and more trees to test for overfitting

rf2 = RandomForestRegressor(
    labelCol="popularity",
    featuresCol="features",
    numTrees=100,
    maxDepth=12,
    featureSubsetStrategy="auto",
    seed=42
)

print("Fitting Model 2 (numTrees=100, maxDepth=12)")
rf_model2 = rf2.fit(train_df)
print("Done")

pred_train2 = rf_model2.transform(train_df)
pred_val2   = rf_model2.transform(val_df)
pred_test2  = rf_model2.transform(test_df)

print("Model 2: numTrees=100, maxDepth=12")
print(f"RMSE  train={eval_rmse.evaluate(pred_train2):.3f}  val={eval_rmse.evaluate(pred_val2):.3f}  test={eval_rmse.evaluate(pred_test2):.3f}")
print(f"R2    train={eval_r2.evaluate(pred_train2):.3f}    val={eval_r2.evaluate(pred_val2):.3f}    test={eval_r2.evaluate(pred_test2):.3f}")
# Out:
# Fitting Model 2 (numTrees=100, maxDepth=12)
# Done
# Model 2: numTrees=100, maxDepth=12
# RMSE  train=2.504  val=2.587  test=2.560
# R2    train=0.751    val=0.742    test=0.742

# %% [markdown]
# ## Feature Importance

# %%
# Feature importances from Model 1
# Higher value = more useful for predicting popularity

import pandas as pd

fi_df = pd.DataFrame({
    "feature": feature_cols,
    "importance": rf_model.featureImportances.toArray()
}).sort_values("importance", ascending=False)

print("Feature importances (Model 1):")
print(fi_df.to_string(index=False))
# Out:
# Feature importances (Model 1):
#           feature  importance
#  album_popularity    0.620257
#      total_tracks    0.213915
#    track_duration    0.062000
#   followers_total    0.048010
# artist_popularity    0.029234
#     log_followers    0.022796
#          explicit    0.003787
#            energy    0.000000
#          liveness    0.000000
#  instrumentalness    0.000000
#      acousticness    0.000000
#       speechiness    0.000000
#          loudness    0.000000
#             tempo    0.000000
#      danceability    0.000000
#              mode    0.000000
#               key    0.000000
#    time_signature    0.000000
# audio_duration_ms    0.000000
#      energy_dance    0.000000
#           valence    0.000000

# %% [markdown]
# # 2nd model using ray

# %%
# !python -m pip install --user --no-cache-dir "ray[data]" "ray[train]" xgboost
# Out:
# Requirement already satisfied: xgboost in /home/darenas/.local/lib/python3.11/site-packages (3.2.0)
# Requirement already satisfied: ray[data] in /home/darenas/.local/lib/python3.11/site-packages (2.55.1)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.11/site-packages (from ray[data]) (8.1.7)
# Requirement already satisfied: filelock in /home/darenas/.local/lib/python3.11/site-packages (from ray[data]) (3.29.0)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.11/site-packages (from ray[data]) (4.19.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from ray[data]) (1.0.6)
# Requirement already satisfied: packaging>=24.2 in /home/darenas/.local/lib/python3.11/site-packages (from ray[data]) (26.2)
# Requirement already satisfied: protobuf>=3.20.3 in /home/darenas/.local/lib/python3.11/site-packages (from ray[data]) (6.33.6)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.11/site-packages (from ray[data]) (6.0.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from ray[data]) (2.31.0)
# Requirement already satisfied: numpy>=1.20 in /opt/conda/lib/python3.11/site-packages (from ray[data]) (1.24.4)
# Requirement already satisfied: pandas>=1.3 in /opt/conda/lib/python3.11/site-packages (from ray[data]) (2.0.3)
# Requirement already satisfied: pyarrow>=9.0.0 in /opt/conda/lib/python3.11/site-packages (from ray[data]) (13.0.0)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from ray[data]) (2023.9.2)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.10.*,!=2.11.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3 in /home/darenas/.local/lib/python3.11/site-packages (from ray[train]) (2.13.4)
# Requirement already satisfied: tensorboardX>=1.9 in /home/darenas/.local/lib/python3.11/site-packages (from ray[train]) (2.6.5)
# Requirement already satisfied: nvidia-nccl-cu12 in /opt/conda/lib/python3.11/site-packages (from xgboost) (2.19.3)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.11/site-packages (from xgboost) (1.11.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.3->ray[data]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.3->ray[data]) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.3->ray[data]) (2023.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/darenas/.local/lib/python3.11/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.10.*,!=2.11.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3->ray[train]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /home/darenas/.local/lib/python3.11/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.10.*,!=2.11.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3->ray[train]) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /home/darenas/.local/lib/python3.11/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.10.*,!=2.11.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3->ray[train]) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/darenas/.local/lib/python3.11/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.10.*,!=2.11.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3->ray[train]) (0.4.2)
# Requirement already satisfied: attrs>=22.2.0 in /opt/conda/lib/python3.11/site-packages (from jsonschema->ray[data]) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.11/site-packages (from jsonschema->ray[data]) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.11/site-packages (from jsonschema->ray[data]) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from jsonschema->ray[data]) (0.10.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->ray[data]) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->ray[data]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->ray[data]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->ray[data]) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.3->ray[data]) (1.16.0)

# %%
#Using Scratch for temp disk space

# %%
import os
from pyspark.ml.functions import vector_to_array

USER = os.environ.get("USER", "user")
BASE = f"/expanse/lustre/scratch/{USER}/temp_project"

RAY_PCA_IN = f"{BASE}/ray_pca_input"
(
    
    df_final
        .select(
        "track_id",
        "popularity",
        "track_name",
        "artist_name",
            
        vector_to_array("features").alias("x")# convert Spark vector -> array<double>
    )
    .write.mode("overwrite").parquet(RAY_PCA_IN)
)
print("Wrote PCA input for Ray to:", RAY_PCA_IN)
# Out:
# Wrote PCA input for Ray to: /expanse/lustre/scratch/darenas/temp_project/ray_pca_input

# %%
#Start Ray locally in notebook (with scratch spilling)
#Ray can spill objects to disk when memory is pressured; set object_spilling_directory to scratch to avoid disk issues

# %%
import ray
import os

RAY_SPILL = f"{BASE}/ray_spill"
os.makedirs(RAY_SPILL, exist_ok=True)

ray.shutdown()
ray.init(num_cpus=8, object_spilling_directory=RAY_SPILL)

print("Ray version:", ray.__version__)
print("Ray resources:", ray.cluster_resources())
print("Ray spill dir:", RAY_SPILL)
# Out:
# 2026-05-31 09:56:25,985	INFO worker.py:2003 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# Ray version: 2.55.1
# Ray resources: {'CPU': 8.0, 'memory': 171488315802.0, 'node:198.202.103.201': 1.0, 'node:__internal_head__': 1.0, 'object_store_memory': 73494992486.0}
# Ray spill dir: /expanse/lustre/scratch/darenas/temp_project/ray_spill
# /home/darenas/.local/lib/python3.11/site-packages/ray/_private/worker.py:2051: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(

# %% [markdown]
# print(ray.cluster_resources())

# %% [markdown]
# # Step 1 RAY PCA Distrubted
# 1A) Read parquet
#  ray reads parquet as a ray dataset

# %%
import ray.data as rd

ds = rd.read_parquet(RAY_PCA_IN)
print(ds.schema())
# Out:
# Parquet dataset sampling:   0%|          | 0.00/2.00 [00:00<?, ? file/s]
# 2026-05-31 09:56:27,813	INFO parquet_datasource.py:1133 -- Estimated parquet encoding ratio is 2.389.
# 2026-05-31 09:56:27,814	INFO parquet_datasource.py:1193 -- Estimated parquet reader batch size at 540114 rows
# Column       Type
# ------       ----
# track_id     string
# popularity   int64
# track_name   string
# artist_name  string
# x            list<element: double not null>

# %% [markdown]
# A2) Compute PCA using distributed batch aggregation (map_batches)
# map_batches is the right pattern for fast batch/NumPy-style transforms in Ray Data

# %%
#map_batches is the way to distrbute the data = faster runtime
#Role of Function: Computes Global mean and covariance by aggreagating sum x and sum of xxT

import numpy as np

def batch_sums(batch): 
        # batch is a dict of numpy arrays when batch_format = numpy
        #shape:(n,d)
        X = np.vstack(batch["x"])   
        n = X.shape[0]
        #(d,)
        sum_x = X.sum(axis= 0)
        #(d, d)
        sum_xxT = X.T @ X                  
        return {"n": [n], "sum_x": [sum_x], "sum_xxT": [sum_xxT]}

# %%
#Aggregate stats over dataset blocks in parallel
stats_ds = ds.map_batches(batch_sums, batch_format="numpy", batch_size=50000)
partials = stats_ds.take_all()

N = int(sum(p["n"] for p in partials))
sum_x = np.sum([p["sum_x"] for p in partials], axis=0)
sum_xxT = np.sum([p["sum_xxT"] for p in partials], axis=0)

mean = sum_x / N
cov = (sum_xxT / N) - np.outer(mean, mean)
# Out:
# 2026-05-31 09:56:28,372	INFO logging.py:416 -- Registered dataset logger for dataset dataset_1_0
# 2026-05-31 09:56:28,392	INFO streaming_executor.py:166 -- Starting execution of Dataset dataset_1_0. Full logs are in /scratch/darenas/job_49921728/ray/session_2026-05-31_09-56-20_730858_516998/logs/ray-data
# 2026-05-31 09:56:28,393	INFO streaming_executor.py:167 -- Execution plan of Dataset dataset_1_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadParquet] -> TaskPoolMapOperator[MapBatches(batch_sums)]
# 2026-05-31 09:56:28,405	WARNING resource_manager.py:169 -- ⚠️  Ray's object store is configured to use only 42.9% of available memory (68.4GiB out of 159.7GiB total). For optimal Ray Data performance, we recommend setting the object store to at least 50% of available memory. You can do this by setting the 'object_store_memory' parameter when calling ray.init() or by setting the RAY_DEFAULT_OBJECT_STORE_MEMORY_PROPORTION environment variable.
# 2026-05-31 09:56:28,408	INFO __init__.py:56 -- Progress will be logged because stdout is a non-interactive terminal.
# 2026-05-31 09:56:29,002	INFO logging_progress.py:174 -- ======= Running Dataset: dataset_1_0 =======
# 2026-05-31 09:56:29,003	INFO logging_progress.py:225 -- Total Progress: 0/?
# 2026-05-31 09:56:29,003	INFO logging_progress.py:227 -- Active & requested resources: 0/8 CPU, 0.0B/34.2GiB object store
# 2026-05-31 09:56:29,005	INFO logging_progress.py:181 --
# 2026-05-31 09:56:29,005	INFO logging_progress.py:231 -- ReadParquet->SplitBlocks(23): 0/1
# 2026-05-31 09:56:29,005	INFO logging_progress.py:233 --   Tasks: 1; Actors: 0; Queued blocks: 8 (0.0B); Resources: 1.0 CPU, 0.0B object store
# 2026-05-31 09:56:29,005	INFO logging_progress.py:231 -- MapBatches(batch_sums): 0/1
# 2026-05-31 09:56:29,006	INFO logging_progress.py:233 --   Tasks: 0; Actors: 0; Queued blocks: 0 (0.0B); Resources: 0.0 CPU, 0.0B object store
# 2026-05-31 09:56:29,006	INFO logging_progress.py:192 -- ============================================
# 2026-05-31 09:56:31,950	INFO streaming_executor.py:294 -- ✔️  Dataset dataset_1_0 execution finished in 3.56 seconds

# %%
# Eigen-decomposition of covariance -> PCA components
eigvals, eigvecs = np.linalg.eigh(cov)     # ascending
idx = np.argsort(eigvals)[::-1]            # descending
eigvals = eigvals[idx]
eigvecs = eigvecs[:, idx]

# %%
explained_var_ratio = eigvals / eigvals.sum()
cum_explained = np.cumsum(explained_var_ratio)

print("Top 10 explained variance ratios:", explained_var_ratio[:10])
print("Cumulative explained variance (top 10):", cum_explained[:10])
print("Feature dimension d =", eigvecs.shape[0])
# Out:
# Top 10 explained variance ratios: [9.70881511e-01 2.90509205e-02 6.73718662e-05 1.64638923e-07
#  2.27695394e-08 9.68458128e-09 6.89043255e-11 0.00000000e+00
#  0.00000000e+00 0.00000000e+00]
# Cumulative explained variance (top 10): [0.97088151 0.99993243 0.9999998  0.99999997 0.99999999 1.
#  1.         1.         1.         1.        ]
# Feature dimension d = 21

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(range(1, len(explained_var_ratio) + 1), explained_var_ratio)
plt.title("Explained Variance Ratio by Principal Component")
plt.xlabel("Principal Component")
plt.ylabel("Explained Variance Ratio")
plt.show()

plt.figure()
plt.plot(range(1, len(cum_explained) + 1), cum_explained)
plt.title("Cumulative Explained Variance")
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")
plt.axhline(0.90, linestyle="--")
plt.show()
# Out:
# WARNING:matplotlib:Matplotlib created a temporary cache directory at /scratch/darenas/job_49921728/matplotlib-qre48lbt because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %% [markdown]
# PCA Interpretation
# The explained variance plot shows that the first principal component captures approximately 97% of the total variance in the dataset, while the second component captures a small additional portion (~2–3%). All remaining components contribute negligible variance.
# The cumulative explained variance indicates that over 99% of the total variance is captured using only the first two principal components. This suggests that the original feature space contains significant redundancy, and that most of the information can be effectively represented in a much lower-dimensional space.

# %%
K = int(np.searchsorted(cum_explained, 0.90) + 1)
print("Selected K to retain ~90% variance:", K)

W = eigvecs[:, :K]   # (d, K)
mu = mean            # (d,)
# Out:
# Selected K to retain ~90% variance: 1

# %%
def project_batch(batch):
    X = np.vstack(batch["x"])
    Z = (X - mu) @ W                      # (n, K)
    batch["pca"] = [row.tolist() for row in Z]
    return batch

ds_pca = ds.map_batches(project_batch, batch_format="numpy", batch_size=50000)

# %%
RAY_PCA_OUT = f"{BASE}/ray_pca_output"
ds_pca.write_parquet(RAY_PCA_OUT)
print("Wrote Ray PCA output to:", RAY_PCA_OUT)
# Out:
# 2026-05-31 09:56:33,615	INFO logging.py:416 -- Registered dataset logger for dataset dataset_4_0
# 2026-05-31 09:56:33,622	INFO streaming_executor.py:166 -- Starting execution of Dataset dataset_4_0. Full logs are in /scratch/darenas/job_49921728/ray/session_2026-05-31_09-56-20_730858_516998/logs/ray-data
# 2026-05-31 09:56:33,623	INFO streaming_executor.py:167 -- Execution plan of Dataset dataset_4_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadParquet] -> TaskPoolMapOperator[MapBatches(project_batch)->Write]
# 2026-05-31 09:56:33,649	INFO logging_progress.py:174 -- ======= Running Dataset: dataset_4_0 =======
# 2026-05-31 09:56:33,650	INFO logging_progress.py:225 -- Total Progress: 0/?
# 2026-05-31 09:56:33,650	INFO logging_progress.py:227 -- Active & requested resources: 0/8 CPU, 0.0B/34.2GiB object store
# 2026-05-31 09:56:33,651	INFO logging_progress.py:181 --
# 2026-05-31 09:56:33,651	INFO logging_progress.py:231 -- ReadParquet->SplitBlocks(23): 0/1
# 2026-05-31 09:56:33,651	INFO logging_progress.py:233 --   Tasks: 1; Actors: 0; Queued blocks: 8 (0.0B); Resources: 1.0 CPU, 0.0B object store
# 2026-05-31 09:56:33,652	INFO logging_progress.py:231 -- MapBatches(project_batch)->Write: 0/1
# 2026-05-31 09:56:33,652	INFO logging_progress.py:233 --   Tasks: 0; Actors: 0; Queued blocks: 0 (0.0B); Resources: 0.0 CPU, 0.0B object store
# 2026-05-31 09:56:33,652	INFO logging_progress.py:192 -- ============================================
# 2026-05-31 09:56:38,357	INFO streaming_executor.py:294 -- ✔️  Dataset dataset_4_0 execution finished in 4.73 seconds
# 2026-05-31 09:56:38,395	INFO dataset.py:5765 -- Data sink Parquet finished. 1278282 rows and 321.5MiB data written.
# Wrote Ray PCA output to: /expanse/lustre/scratch/darenas/temp_project/ray_pca_output

# %% [markdown]
# # Use Ray Train + XGBoost after PCA

# %%
#1) Split your PCA Ray dataset into train / validation / test

train_ds, rest_ds = ds_pca.train_test_split(test_size=0.3, seed=42)
val_ds, test_ds = rest_ds.train_test_split(test_size=0.5, seed=42)

print("Ray splits created")
# Out:
# 2026-05-31 09:56:38,402	INFO logging.py:416 -- Registered dataset logger for dataset dataset_6_0
# 2026-05-31 09:56:38,406	INFO streaming_executor.py:166 -- Starting execution of Dataset dataset_6_0. Full logs are in /scratch/darenas/job_49921728/ray/session_2026-05-31_09-56-20_730858_516998/logs/ray-data
# 2026-05-31 09:56:38,407	INFO streaming_executor.py:167 -- Execution plan of Dataset dataset_6_0: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadParquet] -> TaskPoolMapOperator[MapBatches(project_batch)]
# 2026-05-31 09:56:38,428	INFO logging_progress.py:174 -- ======= Running Dataset: dataset_6_0 =======
# 2026-05-31 09:56:38,429	INFO logging_progress.py:225 -- Total Progress: 0/?
# 2026-05-31 09:56:38,430	INFO logging_progress.py:227 -- Active & requested resources: 0/8 CPU, 0.0B/34.2GiB object store
# 2026-05-31 09:56:38,430	INFO logging_progress.py:181 --
# 2026-05-31 09:56:38,430	INFO logging_progress.py:231 -- ReadParquet->SplitBlocks(23): 0/1
# 2026-05-31 09:56:38,431	INFO logging_progress.py:233 --   Tasks: 1; Actors: 0; Queued blocks: 8 (0.0B); Resources: 1.0 CPU, 0.0B object store
# 2026-05-31 09:56:38,431	INFO logging_progress.py:231 -- MapBatches(project_batch): 0/1
# 2026-05-31 09:56:38,431	INFO logging_progress.py:233 --   Tasks: 0; Actors: 0; Queued blocks: 0 (0.0B); Resources: 0.0 CPU, 0.0B object store
# 2026-05-31 09:56:38,431	INFO logging_progress.py:192 -- ============================================
# 2026-05-31 09:56:42,178	INFO streaming_executor.py:294 -- ✔️  Dataset dataset_6_0 execution finished in 3.77 seconds
# Ray splits created

# %%
def expand_pca(batch):
    P = np.vstack(batch["pca"])  # shape (n, K)
    out = {f"pc{i+1}": P[:, i] for i in range(P.shape[1])}
    out["track_id"] = batch["track_id"]
    out["track_name"] = batch["track_name"]
    out["artist_name"] = batch["artist_name"]
    #label
    out["popularity"] = batch["popularity"]
    return out

train_ds_tab = train_ds.map_batches(expand_pca, batch_format="numpy", batch_size=50000)
val_ds_tab   = val_ds.map_batches(expand_pca, batch_format="numpy", batch_size=50000)
test_ds_tab  = test_ds.map_batches(expand_pca, batch_format="numpy", batch_size=50000)

# %%
train_ds_tab = train_ds_tab.materialize()
val_ds_tab   = val_ds_tab.materialize()
test_ds_tab  = test_ds_tab.materialize()

print("Datasets materialized and ready for training.")
# Out:
# 2026-05-31 09:56:42,241	INFO logging.py:416 -- Registered dataset logger for dataset dataset_15_0
# 2026-05-31 09:56:42,243	INFO streaming_executor.py:166 -- Starting execution of Dataset dataset_15_0. Full logs are in /scratch/darenas/job_49921728/ray/session_2026-05-31_09-56-20_730858_516998/logs/ray-data
# 2026-05-31 09:56:42,243	INFO streaming_executor.py:167 -- Execution plan of Dataset dataset_15_0: InputDataBuffer[Input] -> TaskPoolMapOperator[MapBatches(expand_pca)]
# 2026-05-31 09:56:42,263	INFO logging_progress.py:174 -- ======= Running Dataset: dataset_15_0 =======
# 2026-05-31 09:56:42,264	INFO logging_progress.py:225 -- Total Progress: 0/?
# 2026-05-31 09:56:42,265	INFO logging_progress.py:227 -- Active & requested resources: 0/8 CPU, 0.0B/34.2GiB object store
# 2026-05-31 09:56:42,266	INFO logging_progress.py:181 --
# 2026-05-31 09:56:42,266	INFO logging_progress.py:231 -- MapBatches(expand_pca): 0/1
# 2026-05-31 09:56:42,266	INFO logging_progress.py:233 --   Tasks: 1; Actors: 0; Queued blocks: 16 (0.0B); Resources: 1.0 CPU, 0.0B object store
# 2026-05-31 09:56:42,266	INFO logging_progress.py:192 -- =============================================
# 2026-05-31 09:56:42,682	INFO streaming_executor.py:294 -- ✔️  Dataset dataset_15_0 execution finished in 0.44 seconds
# 2026-05-31 09:56:42,699	INFO logging.py:416 -- Registered dataset logger for dataset dataset_17_0
# 2026-05-31 09:56:42,701	INFO streaming_executor.py:166 -- Starting execution of Dataset dataset_17_0. Full logs are in /scratch/darenas/job_49921728/ray/session_2026-05-31_09-56-20_730858_516998/logs/ray-data
# 2026-05-31 09:56:42,701	INFO streaming_executor.py:167 -- Execution plan of Dataset dataset_17_0: InputDataBuffer[Input] -> TaskPoolMapOperator[MapBatches(expand_pca)]
# 2026-05-31 09:56:42,711	INFO logging_progress.py:174 -- ======= Running Dataset: dataset_17_0 =======
# 2026-05-31 09:56:42,712	INFO logging_progress.py:225 -- Total Progress: 0/?
# 2026-05-31 09:56:42,712	INFO logging_progress.py:227 -- Active & requested resources: 0/8 CPU, 0.0B/34.2GiB object store
# 2026-05-31 09:56:42,712	INFO logging_progress.py:181 --
# 2026-05-31 09:56:42,713	INFO logging_progress.py:231 -- MapBatches(expand_pca): 0/1
# 2026-05-31 09:56:42,713	INFO logging_progress.py:233 --   Tasks: 0; Actors: 0; Queued blocks: 5 (2.4MiB); Resources: 0.0 CPU, 0.0B object store
# 2026-05-31 09:56:42,713	INFO logging_progress.py:192 -- =============================================
# 2026-05-31 09:56:42,874	INFO streaming_executor.py:294 -- ✔️  Dataset dataset_17_0 execution finished in 0.17 seconds
# 2026-05-31 09:56:42,892	INFO logging.py:416 -- Registered dataset logger for dataset dataset_19_0
# 2026-05-31 09:56:42,894	INFO streaming_executor.py:166 -- Starting execution of Dataset dataset_19_0. Full logs are in /scratch/darenas/job_49921728/ray/session_2026-05-31_09-56-20_730858_516998/logs/ray-data
# 2026-05-31 09:56:42,895	INFO streaming_executor.py:167 -- Execution plan of Dataset dataset_19_0: InputDataBuffer[Input] -> TaskPoolMapOperator[MapBatches(expand_pca)]
# 2026-05-31 09:56:42,905	INFO logging_progress.py:174 -- ======= Running Dataset: dataset_19_0 =======
# 2026-05-31 09:56:42,906	INFO logging_progress.py:225 -- Total Progress: 0/?
# 2026-05-31 09:56:42,906	INFO logging_progress.py:227 -- Active & requested resources: 0/8 CPU, 0.0B/34.2GiB object store
# 2026-05-31 09:56:42,906	INFO logging_progress.py:181 --
# 2026-05-31 09:56:42,906	INFO logging_progress.py:231 -- MapBatches(expand_pca): 0/1
# 2026-05-31 09:56:42,907	INFO logging_progress.py:233 --   Tasks: 0; Actors: 0; Queued blocks: 5 (5.6MiB); Resources: 0.0 CPU, 0.0B object store
# 2026-05-31 09:56:42,907	INFO logging_progress.py:192 -- =============================================
# 2026-05-31 09:56:43,077	INFO streaming_executor.py:294 -- ✔️  Dataset dataset_19_0 execution finished in 0.18 seconds
# Datasets materialized and ready for training.

# %%
import xgboost
import time
import ray.train
from ray.train import ScalingConfig
from ray.train.xgboost import XGBoostTrainer, RayTrainReportCallback

def train_xgb_per_worker(config):
    # Get this worker's shard of each dataset
    train_shard = ray.train.get_dataset_shard("train")
    val_shard   = ray.train.get_dataset_shard("validation")

    # Materialize shard -> pandas
    train_df = train_shard.materialize().to_pandas()
    val_df   = val_shard.materialize().to_pandas()

    # Split into X / y
    train_X = train_df.drop(columns=["popularity", "track_id", "track_name", "artist_name"])
    train_y = train_df["popularity"]

    val_X = val_df.drop(columns=["popularity", "track_id", "track_name", "artist_name"])
    val_y = val_df["popularity"]

    # Build DMatrix objects
    dtrain = xgboost.DMatrix(train_X, label=train_y)
    dval   = xgboost.DMatrix(val_X, label=val_y)

    params = {
        "objective": "reg:squarederror",
        "tree_method": "hist",
        "max_depth": 6,
        "eta": 0.05,
        "subsample": 0.8,
        "colsample_bytree": 0.8,
        "eval_metric": "rmse",
    }

    xgboost.train(
        params=params,
        dtrain=dtrain,
        evals=[(dval, "validation")],
        num_boost_round=300,
        callbacks=[RayTrainReportCallback()],
    )

trainer = XGBoostTrainer(
    train_xgb_per_worker,
    datasets={
        "train": train_ds_tab,
        "validation": val_ds_tab,
    },
    scaling_config=ScalingConfig(
        num_workers=3,
        resources_per_worker={"CPU": 2}
    ),
)

# %%
start_time = time.time()
result = trainer.fit()
print("Training complete")
#This shows us every round the model is going thru 3000 times with 3 workers
#print(result.metrics)
end_time = time.time()

print("Training time (seconds):", end_time - start_time)
print("Training time (minutes):", (end_time - start_time)/60)
# Out:
# (TrainController pid=525524) Requesting resources: {'CPU': 2} * 3
# (TrainController pid=525524) Attempting to start training worker group of size 3 with the following resources: [{'CPU': 2}] * 3
# (TrainController pid=525524) Started training worker group of size 3:
# (TrainController pid=525524) - (ip=198.202.103.201, pid=525596) world_rank=0, local_rank=0, node_rank=0
# (TrainController pid=525524) - (ip=198.202.103.201, pid=525597) world_rank=1, local_rank=1, node_rank=0
# (TrainController pid=525524) - (ip=198.202.103.201, pid=525598) world_rank=2, local_rank=2, node_rank=0
# (RayTrainWorker pid=525597) [09:56:48] Task [xgboost.ray-rank=00000001]:42fd8c74a22dac8228e2c40201000000 got rank 1
# (RayTrainWorker pid=525598) Registered dataset logger for dataset dataset_25_0
# (SplitCoordinator pid=525941) Starting execution of Dataset train_21_0. Full logs are in /scratch/darenas/job_49921728/ray/session_2026-05-31_09-56-20_730858_516998/logs/ray-data
# (SplitCoordinator pid=525941) Execution plan of Dataset train_21_0: InputDataBuffer[Input] -> OutputSplitter[split(3, equal=True)]
# (SplitCoordinator pid=525941) ⚠️  Ray's object store is configured to use only 42.9% of available memory (68.4GiB out of 159.7GiB total). For optimal Ray Data performance, we recommend setting the object store to at least 50% of available memory. You can do this by setting the 'object_store_memory' parameter when calling ray.init() or by setting the RAY_DEFAULT_OBJECT_STORE_MEMORY_PROPORTION environment variable.
# (SplitCoordinator pid=525941) [dataset]: A new progress UI is available. To enable, set `ray.data.DataContext.get_current().enable_rich_progress_bars = True` and `ray.data.DataContext.get_current().use_ray_tqdm = False`.
# (SplitCoordinator pid=525941) ✔️  Dataset train_21_0 execution finished in 0.05 seconds
# (pid=525941) Running Dataset train_21_0.: 0.00 row [00:00, ? row/s]
# (pid=525941) - split(3, equal=True):   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# (pid=525597) Running Dataset dataset_27_0.: 0.00 row [00:00, ? row/s]
# (RayTrainWorker pid=525597)
# (pid=525596) Running Dataset dataset_26_0.: 0.00 row [00:00, ? row/s]
# (RayTrainWorker pid=525596)
# (RayTrainWorker pid=525596)
# (pid=525598) Running Dataset dataset_25_0.: 0.00 row [00:00, ? row/s]
# (RayTrainWorker pid=525598)
# (RayTrainWorker pid=525598)
# (RayTrainWorker pid=525597)
# (pid=525940) Running Dataset validation_23_0.: 0.00 row [00:00, ? row/s]
# (pid=525940) - split(3, equal=True):   0%|          | 0.00/1.00 [00:00<?, ? row/s]
# (pid=525597) Running Dataset dataset_29_0.: 0.00 row [00:00, ? row/s]
# (RayTrainWorker pid=525597)
# (RayTrainWorker pid=525597)
# (pid=525596) Running Dataset dataset_28_0.: 0.00 row [00:00, ? row/s]
# (RayTrainWorker pid=525596)
# (RayTrainWorker pid=525596)
# (pid=525598) Running Dataset dataset_30_0.: 0.00 row [00:00, ? row/s]
# (RayTrainWorker pid=525598)
# (RayTrainWorker pid=525598)
# (TrainController pid=525524) [09:56:50] [0]	validation-rmse:5.01527
# (RayTrainWorker pid=525597) Reporting training result 1: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 5.01526543217763)]), validation=False)
# (RayTrainWorker pid=525597) Reporting training result 2: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.999403171803748)]), validation=False)
# (TrainController pid=525524) [09:56:52] [1]	validation-rmse:4.99940
# (TrainController pid=525524) [09:56:54] [2]	validation-rmse:4.98510
# (RayTrainWorker pid=525598) [09:56:48] Task [xgboost.ray-rank=00000002]:d748f277b3b4ce22d31c86d001000000 got rank 2 [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (RayTrainWorker pid=525598) Registered dataset logger for dataset dataset_30_0 [repeated 7x across cluster]
# (SplitCoordinator pid=525940) Starting execution of Dataset validation_23_0. Full logs are in /scratch/darenas/job_49921728/ray/session_2026-05-31_09-56-20_730858_516998/logs/ray-data
# (SplitCoordinator pid=525940) Execution plan of Dataset validation_23_0: InputDataBuffer[Input] -> OutputSplitter[split(3, equal=True)]
# (SplitCoordinator pid=525940) ⚠️  Ray's object store is configured to use only 42.9% of available memory (68.4GiB out of 159.7GiB total). For optimal Ray Data performance, we recommend setting the object store to at least 50% of available memory. You can do this by setting the 'object_store_memory' parameter when calling ray.init() or by setting the RAY_DEFAULT_OBJECT_STORE_MEMORY_PROPORTION environment variable. [repeated 4x across cluster]
# (SplitCoordinator pid=525940) [dataset]: A new progress UI is available. To enable, set `ray.data.DataContext.get_current().enable_rich_progress_bars = True` and `ray.data.DataContext.get_current().use_ray_tqdm = False`. [repeated 4x across cluster]
# (RayTrainWorker pid=525598) ✔️  Dataset dataset_30_0 execution finished in 0.00 seconds [repeated 7x across cluster]
# (TrainController pid=525524) [09:56:56] [3]	validation-rmse:4.97212
# (RayTrainWorker pid=525598) Reporting training result 4: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.972119150164027)]), validation=False) [repeated 10x across cluster]
# (TrainController pid=525524) [09:56:58] [4]	validation-rmse:4.96034
# (TrainController pid=525524) [09:57:00] [5]	validation-rmse:4.94971
# (TrainController pid=525524) [09:57:02] [6]	validation-rmse:4.94006
# (RayTrainWorker pid=525598) Reporting training result 7: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.940055579791664)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:57:04] [7]	validation-rmse:4.93137
# (TrainController pid=525524) [09:57:06] [8]	validation-rmse:4.92344
# (TrainController pid=525524) [09:57:08] [9]	validation-rmse:4.91632
# (RayTrainWorker pid=525598) Reporting training result 10: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.916318638189227)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:57:10] [10]	validation-rmse:4.90981
# (TrainController pid=525524) [09:57:12] [11]	validation-rmse:4.90405
# (TrainController pid=525524) [09:57:14] [12]	validation-rmse:4.89883
# (RayTrainWorker pid=525598) Reporting training result 13: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.898831367413482)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:57:16] [13]	validation-rmse:4.89411
# (TrainController pid=525524) [09:57:18] [14]	validation-rmse:4.88982
# (TrainController pid=525524) [09:57:20] [15]	validation-rmse:4.88599
# (RayTrainWorker pid=525598) Reporting training result 16: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.885986805270629)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:57:22] [16]	validation-rmse:4.88250
# (TrainController pid=525524) [09:57:24] [17]	validation-rmse:4.87937
# (TrainController pid=525524) [09:57:26] [18]	validation-rmse:4.87651
# (RayTrainWorker pid=525598) Reporting training result 19: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.876514576391157)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:57:28] [19]	validation-rmse:4.87399
# (TrainController pid=525524) [09:57:30] [20]	validation-rmse:4.87165
# (TrainController pid=525524) [09:57:32] [21]	validation-rmse:4.86953
# (RayTrainWorker pid=525598) Reporting training result 22: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.869533561521125)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:57:34] [22]	validation-rmse:4.86761
# (TrainController pid=525524) [09:57:36] [23]	validation-rmse:4.86591
# (TrainController pid=525524) [09:57:38] [24]	validation-rmse:4.86436
# (RayTrainWorker pid=525598) Reporting training result 25: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.864364339090933)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:57:40] [25]	validation-rmse:4.86296
# (TrainController pid=525524) [09:57:42] [26]	validation-rmse:4.86172
# (TrainController pid=525524) [09:57:44] [27]	validation-rmse:4.86058
# (RayTrainWorker pid=525598) Reporting training result 28: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.860575520818289)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:57:46] [28]	validation-rmse:4.85955
# (TrainController pid=525524) [09:57:48] [29]	validation-rmse:4.85863
# (TrainController pid=525524) [09:57:50] [30]	validation-rmse:4.85783
# (RayTrainWorker pid=525598) Reporting training result 31: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.857830163621844)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:57:52] [31]	validation-rmse:4.85706
# (TrainController pid=525524) [09:57:54] [32]	validation-rmse:4.85639
# (TrainController pid=525524) [09:57:56] [33]	validation-rmse:4.85577
# (RayTrainWorker pid=525598) Reporting training result 34: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.8557731181681)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:57:58] [34]	validation-rmse:4.85524
# (TrainController pid=525524) [09:58:00] [35]	validation-rmse:4.85473
# (TrainController pid=525524) [09:58:02] [36]	validation-rmse:4.85426
# (RayTrainWorker pid=525598) Reporting training result 37: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.85426453915396)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:58:04] [37]	validation-rmse:4.85385
# (TrainController pid=525524) [09:58:06] [38]	validation-rmse:4.85350
# (TrainController pid=525524) [09:58:08] [39]	validation-rmse:4.85316
# (RayTrainWorker pid=525598) Reporting training result 40: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.853161731685224)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:58:10] [40]	validation-rmse:4.85286
# (TrainController pid=525524) [09:58:12] [41]	validation-rmse:4.85257
# (TrainController pid=525524) [09:58:14] [42]	validation-rmse:4.85232
# (RayTrainWorker pid=525598) Reporting training result 43: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.8523199379088995)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:58:16] [43]	validation-rmse:4.85210
# (TrainController pid=525524) [09:58:18] [44]	validation-rmse:4.85190
# (TrainController pid=525524) [09:58:20] [45]	validation-rmse:4.85173
# (RayTrainWorker pid=525598) Reporting training result 46: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.851731943484385)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:58:22] [46]	validation-rmse:4.85157
# (TrainController pid=525524) [09:58:24] [47]	validation-rmse:4.85144
# (TrainController pid=525524) [09:58:26] [48]	validation-rmse:4.85130
# (RayTrainWorker pid=525598) Reporting training result 49: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.851302432980476)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:58:28] [49]	validation-rmse:4.85119
# (TrainController pid=525524) [09:58:30] [50]	validation-rmse:4.85109
# (TrainController pid=525524) [09:58:32] [51]	validation-rmse:4.85099
# (RayTrainWorker pid=525598) Reporting training result 52: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850990761431601)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:58:34] [52]	validation-rmse:4.85091
# (TrainController pid=525524) [09:58:36] [53]	validation-rmse:4.85084
# (TrainController pid=525524) [09:58:38] [54]	validation-rmse:4.85077
# (RayTrainWorker pid=525598) Reporting training result 55: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850768738949917)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:58:40] [55]	validation-rmse:4.85070
# (TrainController pid=525524) [09:58:42] [56]	validation-rmse:4.85065
# (TrainController pid=525524) [09:58:44] [57]	validation-rmse:4.85059
# (RayTrainWorker pid=525598) Reporting training result 58: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850593778181675)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:58:46] [58]	validation-rmse:4.85055
# (TrainController pid=525524) [09:58:48] [59]	validation-rmse:4.85051
# (TrainController pid=525524) [09:58:51] [60]	validation-rmse:4.85047
# (RayTrainWorker pid=525598) Reporting training result 61: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850471912157747)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:58:53] [61]	validation-rmse:4.85044
# (TrainController pid=525524) [09:58:55] [62]	validation-rmse:4.85041
# (TrainController pid=525524) [09:58:57] [63]	validation-rmse:4.85039
# (RayTrainWorker pid=525598) Reporting training result 64: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.8503895184779955)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:58:59] [64]	validation-rmse:4.85036
# (TrainController pid=525524) [09:59:01] [65]	validation-rmse:4.85035
# (TrainController pid=525524) [09:59:03] [66]	validation-rmse:4.85033
# (RayTrainWorker pid=525598) Reporting training result 67: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850327656102223)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:59:05] [67]	validation-rmse:4.85032
# (TrainController pid=525524) [09:59:07] [68]	validation-rmse:4.85030
# (TrainController pid=525524) [09:59:09] [69]	validation-rmse:4.85028
# (RayTrainWorker pid=525598) Reporting training result 70: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850284849745875)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:59:11] [70]	validation-rmse:4.85028
# (TrainController pid=525524) [09:59:13] [71]	validation-rmse:4.85028
# (TrainController pid=525524) [09:59:15] [72]	validation-rmse:4.85026
# (RayTrainWorker pid=525598) Reporting training result 73: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850264394319088)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:59:17] [73]	validation-rmse:4.85026
# (TrainController pid=525524) [09:59:19] [74]	validation-rmse:4.85024
# (TrainController pid=525524) [09:59:21] [75]	validation-rmse:4.85023
# (RayTrainWorker pid=525598) Reporting training result 76: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850226246662934)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:59:23] [76]	validation-rmse:4.85022
# (TrainController pid=525524) [09:59:25] [77]	validation-rmse:4.85022
# (TrainController pid=525524) [09:59:27] [78]	validation-rmse:4.85021
# (RayTrainWorker pid=525598) Reporting training result 79: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850209576408583)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:59:29] [79]	validation-rmse:4.85020
# (TrainController pid=525524) [09:59:31] [80]	validation-rmse:4.85019
# (TrainController pid=525524) [09:59:33] [81]	validation-rmse:4.85020
# (RayTrainWorker pid=525598) Reporting training result 82: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850200194200283)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:59:35] [82]	validation-rmse:4.85019
# (TrainController pid=525524) [09:59:37] [83]	validation-rmse:4.85019
# (TrainController pid=525524) [09:59:39] [84]	validation-rmse:4.85019
# (RayTrainWorker pid=525598) Reporting training result 85: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850188163394804)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:59:41] [85]	validation-rmse:4.85019
# (TrainController pid=525524) [09:59:43] [86]	validation-rmse:4.85018
# (TrainController pid=525524) [09:59:45] [87]	validation-rmse:4.85019
# (RayTrainWorker pid=525598) Reporting training result 88: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850186746924213)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:59:47] [88]	validation-rmse:4.85018
# (TrainController pid=525524) [09:59:49] [89]	validation-rmse:4.85018
# (TrainController pid=525524) [09:59:51] [90]	validation-rmse:4.85018
# (RayTrainWorker pid=525598) Reporting training result 91: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850180904452442)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:59:53] [91]	validation-rmse:4.85018
# (TrainController pid=525524) [09:59:55] [92]	validation-rmse:4.85018
# (TrainController pid=525524) [09:59:57] [93]	validation-rmse:4.85018
# (RayTrainWorker pid=525598) Reporting training result 94: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850178587293049)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [09:59:59] [94]	validation-rmse:4.85019
# (TrainController pid=525524) [10:00:01] [95]	validation-rmse:4.85019
# (TrainController pid=525524) [10:00:03] [96]	validation-rmse:4.85018
# (RayTrainWorker pid=525598) Reporting training result 97: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850182012173178)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:00:05] [97]	validation-rmse:4.85019
# (TrainController pid=525524) [10:00:07] [98]	validation-rmse:4.85019
# (TrainController pid=525524) [10:00:09] [99]	validation-rmse:4.85019
# (RayTrainWorker pid=525598) Reporting training result 100: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850194869036391)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:00:11] [100]	validation-rmse:4.85019
# (TrainController pid=525524) [10:00:13] [101]	validation-rmse:4.85019
# (TrainController pid=525524) [10:00:15] [102]	validation-rmse:4.85019
# (RayTrainWorker pid=525598) Reporting training result 103: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.85019139373649)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:00:17] [103]	validation-rmse:4.85019
# (TrainController pid=525524) [10:00:19] [104]	validation-rmse:4.85018
# (TrainController pid=525524) [10:00:21] [105]	validation-rmse:4.85019
# (RayTrainWorker pid=525598) Reporting training result 106: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850189165167001)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:00:23] [106]	validation-rmse:4.85018
# (TrainController pid=525524) [10:00:25] [107]	validation-rmse:4.85017
# (TrainController pid=525524) [10:00:27] [108]	validation-rmse:4.85018
# (RayTrainWorker pid=525598) Reporting training result 109: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.85018403028532)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:00:29] [109]	validation-rmse:4.85020
# (TrainController pid=525524) [10:00:31] [110]	validation-rmse:4.85019
# (TrainController pid=525524) [10:00:33] [111]	validation-rmse:4.85019
# (RayTrainWorker pid=525598) Reporting training result 112: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850190657379938)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:00:35] [112]	validation-rmse:4.85019
# (TrainController pid=525524) [10:00:37] [113]	validation-rmse:4.85020
# (TrainController pid=525524) [10:00:39] [114]	validation-rmse:4.85021
# (RayTrainWorker pid=525598) Reporting training result 115: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850206588770989)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:00:41] [115]	validation-rmse:4.85023
# (TrainController pid=525524) [10:00:43] [116]	validation-rmse:4.85022
# (TrainController pid=525524) [10:00:45] [117]	validation-rmse:4.85022
# (RayTrainWorker pid=525598) Reporting training result 118: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850217239498455)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:00:47] [118]	validation-rmse:4.85022
# (TrainController pid=525524) [10:00:49] [119]	validation-rmse:4.85021
# (TrainController pid=525524) [10:00:51] [120]	validation-rmse:4.85022
# (RayTrainWorker pid=525598) Reporting training result 121: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.8502184049148855)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:00:53] [121]	validation-rmse:4.85023
# (TrainController pid=525524) [10:00:55] [122]	validation-rmse:4.85024
# (TrainController pid=525524) [10:00:57] [123]	validation-rmse:4.85023
# (RayTrainWorker pid=525598) Reporting training result 124: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850228925440013)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:00:59] [124]	validation-rmse:4.85023
# (TrainController pid=525524) [10:01:01] [125]	validation-rmse:4.85024
# (TrainController pid=525524) [10:01:03] [126]	validation-rmse:4.85024
# (RayTrainWorker pid=525598) Reporting training result 127: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850242252376818)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:01:05] [127]	validation-rmse:4.85024
# (TrainController pid=525524) [10:01:07] [128]	validation-rmse:4.85023
# (TrainController pid=525524) [10:01:09] [129]	validation-rmse:4.85022
# (RayTrainWorker pid=525598) Reporting training result 130: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850218650173567)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:01:11] [130]	validation-rmse:4.85022
# (TrainController pid=525524) [10:01:13] [131]	validation-rmse:4.85023
# (TrainController pid=525524) [10:01:15] [132]	validation-rmse:4.85023
# (RayTrainWorker pid=525598) Reporting training result 133: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850227283225484)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:01:17] [133]	validation-rmse:4.85023
# (TrainController pid=525524) [10:01:19] [134]	validation-rmse:4.85023
# (TrainController pid=525524) [10:01:21] [135]	validation-rmse:4.85023
# (RayTrainWorker pid=525598) Reporting training result 136: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.8502306135771)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:01:23] [136]	validation-rmse:4.85023
# (TrainController pid=525524) [10:01:25] [137]	validation-rmse:4.85024
# (TrainController pid=525524) [10:01:27] [138]	validation-rmse:4.85024
# (RayTrainWorker pid=525598) Reporting training result 139: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850239222871937)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:01:29] [139]	validation-rmse:4.85025
# (TrainController pid=525524) [10:01:31] [140]	validation-rmse:4.85025
# (TrainController pid=525524) [10:01:33] [141]	validation-rmse:4.85025
# (RayTrainWorker pid=525598) Reporting training result 142: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.8502549393782495)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:01:35] [142]	validation-rmse:4.85025
# (TrainController pid=525524) [10:01:37] [143]	validation-rmse:4.85024
# (TrainController pid=525524) [10:01:39] [144]	validation-rmse:4.85024
# (RayTrainWorker pid=525598) Reporting training result 145: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850237140795926)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:01:41] [145]	validation-rmse:4.85024
# (TrainController pid=525524) [10:01:44] [146]	validation-rmse:4.85025
# (TrainController pid=525524) [10:01:46] [147]	validation-rmse:4.85025
# (RayTrainWorker pid=525598) Reporting training result 148: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850250385904535)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:01:48] [148]	validation-rmse:4.85025
# (TrainController pid=525524) [10:01:50] [149]	validation-rmse:4.85025
# (TrainController pid=525524) [10:01:52] [150]	validation-rmse:4.85026
# (RayTrainWorker pid=525598) Reporting training result 151: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.85025813008073)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:01:54] [151]	validation-rmse:4.85027
# (TrainController pid=525524) [10:01:56] [152]	validation-rmse:4.85028
# (TrainController pid=525524) [10:01:58] [153]	validation-rmse:4.85028
# (RayTrainWorker pid=525598) Reporting training result 154: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850277789660149)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:02:00] [154]	validation-rmse:4.85026
# (TrainController pid=525524) [10:02:02] [155]	validation-rmse:4.85026
# (TrainController pid=525524) [10:02:04] [156]	validation-rmse:4.85026
# (RayTrainWorker pid=525598) Reporting training result 157: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850258506728904)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:02:06] [157]	validation-rmse:4.85025
# (TrainController pid=525524) [10:02:08] [158]	validation-rmse:4.85026
# (TrainController pid=525524) [10:02:10] [159]	validation-rmse:4.85027
# (RayTrainWorker pid=525598) Reporting training result 160: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850267001270809)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:02:12] [160]	validation-rmse:4.85026
# (TrainController pid=525524) [10:02:14] [161]	validation-rmse:4.85026
# (TrainController pid=525524) [10:02:16] [162]	validation-rmse:4.85026
# (RayTrainWorker pid=525598) Reporting training result 163: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850256657072648)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:02:18] [163]	validation-rmse:4.85026
# (TrainController pid=525524) [10:02:20] [164]	validation-rmse:4.85026
# (TrainController pid=525524) [10:02:22] [165]	validation-rmse:4.85026
# (RayTrainWorker pid=525598) Reporting training result 166: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850255626231629)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:02:24] [166]	validation-rmse:4.85024
# (TrainController pid=525524) [10:02:26] [167]	validation-rmse:4.85026
# (TrainController pid=525524) [10:02:28] [168]	validation-rmse:4.85025
# (RayTrainWorker pid=525598) Reporting training result 169: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850250824056396)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:02:30] [169]	validation-rmse:4.85025
# (TrainController pid=525524) [10:02:32] [170]	validation-rmse:4.85027
# (TrainController pid=525524) [10:02:34] [171]	validation-rmse:4.85028
# (RayTrainWorker pid=525598) Reporting training result 172: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850279142005535)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:02:36] [172]	validation-rmse:4.85027
# (TrainController pid=525524) [10:02:38] [173]	validation-rmse:4.85026
# (TrainController pid=525524) [10:02:40] [174]	validation-rmse:4.85026
# (RayTrainWorker pid=525598) Reporting training result 175: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850260139448547)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:02:42] [175]	validation-rmse:4.85026
# (TrainController pid=525524) [10:02:44] [176]	validation-rmse:4.85025
# (TrainController pid=525524) [10:02:46] [177]	validation-rmse:4.85025
# (RayTrainWorker pid=525598) Reporting training result 178: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.8502506683245885)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:02:48] [178]	validation-rmse:4.85025
# (TrainController pid=525524) [10:02:50] [179]	validation-rmse:4.85025
# (TrainController pid=525524) [10:02:52] [180]	validation-rmse:4.85025
# (RayTrainWorker pid=525598) Reporting training result 181: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850252772675224)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:02:54] [181]	validation-rmse:4.85024
# (TrainController pid=525524) [10:02:56] [182]	validation-rmse:4.85026
# (TrainController pid=525524) [10:02:58] [183]	validation-rmse:4.85026
# (RayTrainWorker pid=525598) Reporting training result 184: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850258408376236)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:03:00] [184]	validation-rmse:4.85026
# (TrainController pid=525524) [10:03:02] [185]	validation-rmse:4.85025
# (TrainController pid=525524) [10:03:04] [186]	validation-rmse:4.85025
# (RayTrainWorker pid=525598) Reporting training result 187: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.8502485735289795)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:03:06] [187]	validation-rmse:4.85026
# (TrainController pid=525524) [10:03:08] [188]	validation-rmse:4.85025
# (TrainController pid=525524) [10:03:10] [189]	validation-rmse:4.85026
# (RayTrainWorker pid=525598) Reporting training result 190: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850260177162981)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:03:12] [190]	validation-rmse:4.85026
# (TrainController pid=525524) [10:03:14] [191]	validation-rmse:4.85026
# (TrainController pid=525524) [10:03:16] [192]	validation-rmse:4.85026
# (RayTrainWorker pid=525598) Reporting training result 193: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850256655341384)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:03:18] [193]	validation-rmse:4.85027
# (TrainController pid=525524) [10:03:20] [194]	validation-rmse:4.85026
# (TrainController pid=525524) [10:03:22] [195]	validation-rmse:4.85027
# (RayTrainWorker pid=525598) Reporting training result 196: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850266969730567)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:03:24] [196]	validation-rmse:4.85026
# (TrainController pid=525524) [10:03:26] [197]	validation-rmse:4.85025
# (TrainController pid=525524) [10:03:28] [198]	validation-rmse:4.85024
# (RayTrainWorker pid=525598) Reporting training result 199: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850243436254058)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:03:30] [199]	validation-rmse:4.85025
# (TrainController pid=525524) [10:03:32] [200]	validation-rmse:4.85025
# (TrainController pid=525524) [10:03:34] [201]	validation-rmse:4.85025
# (RayTrainWorker pid=525598) Reporting training result 202: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.8502491645103865)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:03:36] [202]	validation-rmse:4.85024
# (TrainController pid=525524) [10:03:38] [203]	validation-rmse:4.85025
# (TrainController pid=525524) [10:03:40] [204]	validation-rmse:4.85025
# (RayTrainWorker pid=525598) Reporting training result 205: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.8502523178171515)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:03:42] [205]	validation-rmse:4.85024
# (TrainController pid=525524) [10:03:44] [206]	validation-rmse:4.85025
# (TrainController pid=525524) [10:03:46] [207]	validation-rmse:4.85025
# (RayTrainWorker pid=525598) Reporting training result 208: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850253597124993)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:03:48] [208]	validation-rmse:4.85024
# (TrainController pid=525524) [10:03:50] [209]	validation-rmse:4.85024
# (TrainController pid=525524) [10:03:52] [210]	validation-rmse:4.85024
# (RayTrainWorker pid=525598) Reporting training result 211: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850243173728201)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:03:54] [211]	validation-rmse:4.85025
# (TrainController pid=525524) [10:03:56] [212]	validation-rmse:4.85025
# (TrainController pid=525524) [10:03:58] [213]	validation-rmse:4.85025
# (RayTrainWorker pid=525598) Reporting training result 214: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850251944065435)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:04:00] [214]	validation-rmse:4.85024
# (TrainController pid=525524) [10:04:02] [215]	validation-rmse:4.85025
# (TrainController pid=525524) [10:04:04] [216]	validation-rmse:4.85024
# (RayTrainWorker pid=525598) Reporting training result 217: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850244240404912)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:04:06] [217]	validation-rmse:4.85025
# (TrainController pid=525524) [10:04:08] [218]	validation-rmse:4.85026
# (TrainController pid=525524) [10:04:10] [219]	validation-rmse:4.85025
# (RayTrainWorker pid=525598) Reporting training result 220: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850253604780625)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:04:12] [220]	validation-rmse:4.85024
# (TrainController pid=525524) [10:04:14] [221]	validation-rmse:4.85024
# (TrainController pid=525524) [10:04:16] [222]	validation-rmse:4.85025
# (RayTrainWorker pid=525598) Reporting training result 223: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850251066618193)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:04:18] [223]	validation-rmse:4.85024
# (TrainController pid=525524) [10:04:20] [224]	validation-rmse:4.85024
# (TrainController pid=525524) [10:04:22] [225]	validation-rmse:4.85024
# (RayTrainWorker pid=525598) Reporting training result 226: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850243680269382)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:04:24] [226]	validation-rmse:4.85025
# (TrainController pid=525524) [10:04:26] [227]	validation-rmse:4.85025
# (TrainController pid=525524) [10:04:28] [228]	validation-rmse:4.85025
# (RayTrainWorker pid=525598) Reporting training result 229: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850247799515115)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:04:30] [229]	validation-rmse:4.85025
# (TrainController pid=525524) [10:04:32] [230]	validation-rmse:4.85025
# (TrainController pid=525524) [10:04:34] [231]	validation-rmse:4.85026
# (RayTrainWorker pid=525598) Reporting training result 232: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850259358079151)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:04:36] [232]	validation-rmse:4.85026
# (TrainController pid=525524) [10:04:39] [233]	validation-rmse:4.85026
# (TrainController pid=525524) [10:04:41] [234]	validation-rmse:4.85027
# (RayTrainWorker pid=525598) Reporting training result 235: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850266470183341)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:04:43] [235]	validation-rmse:4.85026
# (TrainController pid=525524) [10:04:45] [236]	validation-rmse:4.85025
# (TrainController pid=525524) [10:04:47] [237]	validation-rmse:4.85025
# (RayTrainWorker pid=525598) Reporting training result 238: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850249821260543)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:04:49] [238]	validation-rmse:4.85025
# (TrainController pid=525524) [10:04:51] [239]	validation-rmse:4.85024
# (TrainController pid=525524) [10:04:53] [240]	validation-rmse:4.85023
# (RayTrainWorker pid=525598) Reporting training result 241: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850225082600566)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:04:55] [241]	validation-rmse:4.85023
# (TrainController pid=525524) [10:04:57] [242]	validation-rmse:4.85023
# (TrainController pid=525524) [10:04:59] [243]	validation-rmse:4.85024
# (RayTrainWorker pid=525598) Reporting training result 244: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850241110547964)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:05:01] [244]	validation-rmse:4.85024
# (TrainController pid=525524) [10:05:03] [245]	validation-rmse:4.85025
# (TrainController pid=525524) [10:05:05] [246]	validation-rmse:4.85026
# (RayTrainWorker pid=525598) Reporting training result 247: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850256389764386)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:05:07] [247]	validation-rmse:4.85026
# (TrainController pid=525524) [10:05:09] [248]	validation-rmse:4.85025
# (TrainController pid=525524) [10:05:11] [249]	validation-rmse:4.85026
# (RayTrainWorker pid=525598) Reporting training result 250: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.85025972801001)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:05:13] [250]	validation-rmse:4.85025
# (TrainController pid=525524) [10:05:15] [251]	validation-rmse:4.85026
# (TrainController pid=525524) [10:05:17] [252]	validation-rmse:4.85025
# (RayTrainWorker pid=525598) Reporting training result 253: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850249506850398)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:05:19] [253]	validation-rmse:4.85026
# (TrainController pid=525524) [10:05:21] [254]	validation-rmse:4.85026
# (TrainController pid=525524) [10:05:23] [255]	validation-rmse:4.85026
# (RayTrainWorker pid=525598) Reporting training result 256: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850264777526598)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:05:25] [256]	validation-rmse:4.85027
# (TrainController pid=525524) [10:05:27] [257]	validation-rmse:4.85026
# (TrainController pid=525524) [10:05:29] [258]	validation-rmse:4.85027
# (RayTrainWorker pid=525598) Reporting training result 259: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850273149856178)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:05:31] [259]	validation-rmse:4.85028
# (TrainController pid=525524) [10:05:33] [260]	validation-rmse:4.85029
# (TrainController pid=525524) [10:05:35] [261]	validation-rmse:4.85029
# (RayTrainWorker pid=525598) Reporting training result 262: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850285389163813)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:05:37] [262]	validation-rmse:4.85028
# (TrainController pid=525524) [10:05:39] [263]	validation-rmse:4.85028
# (TrainController pid=525524) [10:05:41] [264]	validation-rmse:4.85028
# (RayTrainWorker pid=525598) Reporting training result 265: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850281082303263)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:05:43] [265]	validation-rmse:4.85028
# (TrainController pid=525524) [10:05:45] [266]	validation-rmse:4.85030
# (TrainController pid=525524) [10:05:47] [267]	validation-rmse:4.85030
# (RayTrainWorker pid=525598) Reporting training result 268: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850299121982351)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:05:49] [268]	validation-rmse:4.85030
# (TrainController pid=525524) [10:05:51] [269]	validation-rmse:4.85030
# (TrainController pid=525524) [10:05:53] [270]	validation-rmse:4.85029
# (RayTrainWorker pid=525598) Reporting training result 271: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850285262353817)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:05:55] [271]	validation-rmse:4.85029
# (TrainController pid=525524) [10:05:57] [272]	validation-rmse:4.85028
# (TrainController pid=525524) [10:05:59] [273]	validation-rmse:4.85027
# (RayTrainWorker pid=525598) Reporting training result 274: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.85026977928067)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:06:01] [274]	validation-rmse:4.85029
# (TrainController pid=525524) [10:06:03] [275]	validation-rmse:4.85029
# (TrainController pid=525524) [10:06:05] [276]	validation-rmse:4.85028
# (RayTrainWorker pid=525598) Reporting training result 277: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850283532239467)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:06:07] [277]	validation-rmse:4.85029
# (TrainController pid=525524) [10:06:09] [278]	validation-rmse:4.85028
# (TrainController pid=525524) [10:06:11] [279]	validation-rmse:4.85028
# (RayTrainWorker pid=525598) Reporting training result 280: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850282189934119)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:06:13] [280]	validation-rmse:4.85028
# (TrainController pid=525524) [10:06:15] [281]	validation-rmse:4.85028
# (TrainController pid=525524) [10:06:17] [282]	validation-rmse:4.85029
# (RayTrainWorker pid=525598) Reporting training result 283: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850288399638676)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:06:19] [283]	validation-rmse:4.85029
# (TrainController pid=525524) [10:06:21] [284]	validation-rmse:4.85029
# (TrainController pid=525524) [10:06:23] [285]	validation-rmse:4.85028
# (RayTrainWorker pid=525598) Reporting training result 286: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850279862871647)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:06:25] [286]	validation-rmse:4.85030
# (TrainController pid=525524) [10:06:27] [287]	validation-rmse:4.85030
# (TrainController pid=525524) [10:06:29] [288]	validation-rmse:4.85028
# (RayTrainWorker pid=525598) Reporting training result 289: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850284698523037)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:06:31] [289]	validation-rmse:4.85029
# (TrainController pid=525524) [10:06:33] [290]	validation-rmse:4.85030
# (TrainController pid=525524) [10:06:35] [291]	validation-rmse:4.85029
# (RayTrainWorker pid=525598) Reporting training result 292: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850288693901202)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:06:37] [292]	validation-rmse:4.85029
# (TrainController pid=525524) [10:06:39] [293]	validation-rmse:4.85030
# (TrainController pid=525524) [10:06:41] [294]	validation-rmse:4.85030
# (RayTrainWorker pid=525598) Reporting training result 295: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850297017413794)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:06:43] [295]	validation-rmse:4.85030
# (TrainController pid=525524) [10:06:45] [296]	validation-rmse:4.85031
# (TrainController pid=525524) [10:06:47] [297]	validation-rmse:4.85031
# (RayTrainWorker pid=525598) Reporting training result 298: TrainingReport(checkpoint=None, metrics=OrderedDict([('validation-rmse', 4.850305357044957)]), validation=False) [repeated 9x across cluster]
# (TrainController pid=525524) [10:06:49] [298]	validation-rmse:4.85030
# (TrainController pid=525524) [10:06:51] [299]	validation-rmse:4.85030
# (RayTrainWorker pid=525596) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/darenas/ray_results/ray_train_run-2026-05-31_09-56-44/checkpoint_2026-05-31_10-06-51.752508)
# (RayTrainWorker pid=525596) Reporting training result 301: TrainingReport(checkpoint=Checkpoint(filesystem=local, path=/home/darenas/ray_results/ray_train_run-2026-05-31_09-56-44/checkpoint_2026-05-31_10-06-51.752508), metrics=OrderedDict([('validation-rmse', 4.850297381985854)]), validation=False)
# Training complete
# Training time (seconds): 613.9608898162842
# Training time (minutes): 10.232681496938069

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Get trained model from checkpoint
checkpoint = result.checkpoint
booster = RayTrainReportCallback.get_model(checkpoint)

print("Loaded trained XGBoost model from Ray")

#  Load test data from Ray → pandas
test_df = test_ds_tab.materialize().to_pandas()

# Split features and label
y_test = test_df["popularity"]
X_test = test_df.drop(columns=["popularity", "track_id", "track_name", "artist_name"])

# Convert to DMatrix
dtest = xgboost.DMatrix(X_test, label=y_test)

# Make predictions
pred_test = booster.predict(dtest)
# Metrics
rmse_test = np.sqrt(mean_squared_error(y_test, pred_test))
r2_test = r2_score(y_test, pred_test)

print("=== MODEL 2: Ray PCA + XGBoost (TEST) ===")
print("RMSE test:", rmse_test)
print("R2 test  :", r2_test)
# Out:
# Loaded trained XGBoost model from Ray
# === MODEL 2: Ray PCA + XGBoost (TEST) ===
# RMSE test: 4.874699123668092
# R2 test  : 0.07056061964886073

# %% [markdown]
# The XGBoost model achieved a validation RMSE of approximately 4.86, meaning that predictions deviate from the true popularity values by about 5 points on average.
# However, the corresponding R² score is low (~0.07), indicating that the model explains only a small portion of the variance in the target variable. This suggests that while predictions are reasonably close numerically, the model is not capturing strong predictive patterns in the data.
# This result implies that either the available features are weak predictors of popularity or that the relationship between features and popularity is complex and difficult to model.

# %%
pred_test = spark.createDataFrame(test_df)

pred_test.orderBy(F.desc("popularity")).show(10, truncate=False)
# Out:
# +-------------------+----------------------+-------------------------------------------------------------+-----------------+----------+------------------+
# |pc1                |track_id              |track_name                                                   |artist_name      |popularity|prediction        |
# +-------------------+----------------------+-------------------------------------------------------------+-----------------+----------+------------------+
# |-1.253020672680612 |6393yGahSJ9slVdOwSxOVR|Pink Pony Club                                               |Chappell Roan    |87        |3.863180637359619 |
# |-1.203482142036836 |6si71supnBUhddjR2FJc2L|White Flag                                                   |Dido             |78        |5.006976127624512 |
# |-1.2799012420829667|6mTvwBzWTGDOVeCNQEqtOE|Soch Na Sake                                                 |Arijit Singh     |76        |4.356795310974121 |
# |-1.0929539662797687|5ds1Hh3lo4JUF2vflqyayK|Manos de Tijera                                              |Yiyo Sarante     |72        |4.771185398101807 |
# |-1.2473007809081356|5h5TUj8pU2WhdSeJx9BnX2|Pelele                                                       |Morad            |71        |3.851830244064331 |
# |-1.2689188441064567|41pOIT2t1rvr2Trg1HQChZ|Radio/Video                                                  |System Of A Down |71        |3.7007620334625244|
# |-1.2141881146448799|6ycaCm185cxHgc6ZAGgoMV|Ô Queiroz - Live At HSBC Arena/Rio de Janeiro(RJ)-Brazil/2012|Grupo Revelação  |70        |4.193398475646973 |
# |-0.7076006390330069|3gWBWLw3J3XTy3QTo36GqJ|Espresso Macchiato                                           |Tommy Cash       |70        |4.010439872741699 |
# |-1.2746076723264221|4hceSKjrkDTO0nMKFcb3sj|Villano Antillano: Bzrp Music Sessions, Vol. 51              |Villano Antillano|69        |4.356795310974121 |
# |-0.7588477880820244|3CmpoZ5ETJEzx739AhhQFh|INZM                                                         |Number_i         |69        |4.182017803192139 |
# +-------------------+----------------------+-------------------------------------------------------------+-----------------+----------+------------------+
# only showing top 10 rows

# %%
# ----- TRAIN PREDICTIONS -----

# Convert Ray → pandas
train_df = train_ds_tab.to_pandas()

# Split features + label
y_train = train_df["popularity"]

X_train = train_df.drop(columns=[
    "popularity",
    "track_id",
    "track_name",
    "artist_name"
])

# Predict
dtrain = xgboost.DMatrix(X_train)
train_preds = booster.predict(dtrain)

# Add predictions back
train_df["prediction"] = train_preds

# Convert to Spark (for .show())
pred_train = spark.createDataFrame(train_df)

# %%
print("Train examples")

pred_train.select(
    "track_id",
    "track_name",
    "artist_name",
    "popularity",
    "prediction"
)\
.orderBy(F.desc("popularity"))\
.show(10, truncate=False)
# Out:
# Train examples
# +----------------------+-------------------------+---------------+----------+------------------+
# |track_id              |track_name               |artist_name    |popularity|prediction        |
# +----------------------+-------------------------+---------------+----------+------------------+
# |6PGoSes0D9eUDeeAafB2As|LOVE. FEAT. ZACARI.      |Zacari         |85        |4.356795310974121 |
# |1Fid2jjqsHViMX6xNH70hE|Atlantis                 |Seafret        |84        |4.9588236808776855|
# |3MJ6lFNV12FSHAOzTzkwxz|Smile                    |Morgan Wallen  |83        |3.7007620334625244|
# |5hnyJvgoWiQUYZttV4wXy6|Chasing Cars             |Snow Patrol    |83        |4.025641918182373 |
# |0xmjwnQ3FNE6HuWCt2nHdZ|Where Is The Love?       |Black Eyed Peas|81        |4.041967391967773 |
# |3QQvSQKV8YmQxGolwwWe59|CATFISH                  |Doechii        |81        |3.851830244064331 |
# |4lhqb6JvbHId48OUJGwymk|Hey Brother              |Avicii         |81        |4.356795310974121 |
# |2gfn28JSINCJGLrUimmu0l|Cantada Boba - Ao Vivo   |Jorge & Mateus |80        |4.356795310974121 |
# |2x8evxqUlF0eRabbW2JBJd|Fluorescent Adolescent   |Arctic Monkeys |78        |4.356795310974121 |
# |6otePxalBK8AVa20xhZYVQ|MIENTRAS ME CURO DEL CORA|KAROL G        |78        |4.356795310974121 |
# +----------------------+-------------------------+---------------+----------+------------------+
# only showing top 10 rows

# %%
# ----- VALIDATION PREDICTIONS -----

val_df = val_ds_tab.to_pandas()

y_val = val_df["popularity"]

X_val = val_df.drop(columns=[
    "popularity",
    "track_id",
    "track_name",
    "artist_name"
])

dval = xgboost.DMatrix(X_val)
val_preds = booster.predict(dval)

val_df["prediction"] = val_preds

pred_val = spark.createDataFrame(val_df)

# %%
pred_val.select(
    "track_id",
    "track_name",
    "artist_name",
    "popularity",
    "prediction"
)\
.sample(fraction=0.0001)\
.show(10, truncate=False)
# Out:
# +----------------------+-----------------------------------+-----------------------+----------+-------------------+
# |track_id              |track_name                         |artist_name            |popularity|prediction         |
# +----------------------+-----------------------------------+-----------------------+----------+-------------------+
# |3uJTmePutPAyxqitxHxbqC|Beer Me                            |The Inner Urge         |0         |0.5282255411148071 |
# |42NvWJg2aLo0pnxgklYo4Y|Forever by Your Side               |Oz Nelson              |0         |0.4664263129234314 |
# |104NB0Uituus9x8jpWGqtl|Cloud Spotting                     |Best Relaxing Spa Music|0         |0.6363356709480286 |
# |1F3znxtkhrilUUMTLllZWL|Little Red Riding Hood Hit The Road|John Greaves           |2         |1.5687470436096191 |
# |4BtRgyXvNC3px6m3Lm4DyG|우리 모든 날들 (김필) (-2키)       |뮤직마루               |0         |0.2602924704551697 |
# |4Cd4hf97PAV0Mu4RFEAa0G|夜的樂章                           |霧會散去雨會停         |0         |0.20076006650924683|
# |4OvN391pwGceExZo6Nowxf|Afternoon Tea                      |Stephen Porter         |0         |1.2164217233657837 |
# |4bRpOErKpKLf9xfgmUcC1u|I Got Paid                         |The Modern Jazz Quartet|0         |4.010439872741699  |
# |1plhkuLuDiilUAnisZdOw7|Darkside                           |daniela lozada         |0         |0.19527342915534973|
# |1sov8FfHEFqBFVGpSsilrc|Always - Easy Extended             |Timmy Bow              |7         |0.8557276129722595 |
# +----------------------+-----------------------------------+-----------------------+----------+-------------------+
# only showing top 10 rows

# %% [markdown]
# Model Behavior Interpretation
# Inspection of the predicted values shows that the model consistently produces very small predictions, typically in the range of 0–4, regardless of the true popularity values. Even when the actual popularity is higher (e.g., 7 or more), the model significantly underestimates the value.
# This indicates that the model has learned a biased representation of the data, heavily favoring low popularity predictions. As a result, the model never predicts values above the classification threshold (70), which explains the confusion matrix results showing zero true positives.
# This behavior is consistent with the low R² score and indicates that the model fails to capture meaningful relationships between the features and the target variable.

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 1) Get test data as pandas
test_pdf = test_ds_tab.to_pandas()

# 2) Build X_test
X_test = test_pdf.drop(columns=[
    "popularity",
    "track_id",
    "track_name",
    "artist_name"
])

# 3) Predict with XGBoost
dtest = xgboost.DMatrix(X_test)
test_preds = booster.predict(dtest)   # <-- numeric array

# 4) Add numeric predictions to pandas df
test_pdf["prediction"] = test_preds

# 5) Create binary labels
y_true = (test_pdf["popularity"] >= 70).astype(int)
y_pred = (test_pdf["prediction"] >= 70).astype(int)

# 6) Confusion matrix
cm = confusion_matrix(y_true, y_pred)
print(cm)

# 7) Heatmap
sns.heatmap(
    cm,
    annot=True,
    fmt="g",
    xticklabels=["Not Popular (<70)", "Popular (>=70)"],
    yticklabels=["Not Popular (<70)", "Popular (>=70)"]
)

plt.ylabel("Actual", fontsize=13)
plt.title("Confusion Matrix", fontsize=17, pad=20)
plt.gca().xaxis.set_label_position("top")
plt.xlabel("Prediction", fontsize=13)
plt.gca().xaxis.tick_top()

plt.gca().figure.subplots_adjust(bottom=0.2)
plt.gca().figure.text(0.5, 0.05, "Prediction", ha="center", fontsize=13)
plt.show()

# 8) Optional classification report
print(classification_report(y_true, y_pred))
# Out:
# [[191735      0]
#  [     8      0]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    191735
#            1       0.00      0.00      0.00         8
#
#     accuracy                           1.00    191743
#    macro avg       0.50      0.50      0.50    191743
# weighted avg       1.00      1.00      1.00    191743
# /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# The confusion matrix reveals that the model predicts all observations as “not popular.” This occurs because the predicted values are consistently very low (typically between 0 and 4), which never exceed the classification threshold of 70. As a result, the model produces zero true positives and fails to identify any high-popularity tracks.
# This behavior indicates severe underfitting, where the model is unable to learn meaningful distinctions between low and high popularity songs. Instead of capturing patterns in the data, the model collapses predictions to a narrow low-value range, effectively ignoring the variability in the target variable.

# %% [markdown]
# # IMPROVING MODEL

# %%
#restarting and no pca to improve model
from pyspark.ml.feature import VectorAssembler

feature_cols = [
    "followers_total", "artist_popularity", "album_popularity", "total_tracks",
    "track_duration", "explicit", "log_followers", "energy_dance"
] + audio_cols

assembler = VectorAssembler(
    inputCols=feature_cols,
    outputCol="features_raw",
    handleInvalid="keep"
)

df_no_pca = assembler.transform(df_clean).select(
    "track_id",
    "track_name",
    "artist_name",
    "popularity",
    "features_raw"
)

# %%
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

pdf = df_no_pca.select("track_id", "track_name", "artist_name", "popularity", "features_raw") \
               .limit(200000).toPandas()

X = np.vstack(pdf["features_raw"].apply(lambda v: v.toArray()))
y = pdf["popularity"].values

X_train, X_test, y_train, y_test, train_meta, test_meta = train_test_split(
    X, y, pdf[["track_id", "track_name", "artist_name"]],
    test_size=0.2,
    random_state=42
)

xgb = XGBRegressor(
    n_estimators=500,
    max_depth=8,
    learning_rate=0.05,
    subsample=0.9,
    colsample_bytree=0.9,
    min_child_weight=3,
    reg_lambda=1.0,
    objective="reg:squarederror",
    tree_method="hist",
    random_state=42
)

xgb.fit(X_train, y_train)

pred_train = xgb.predict(X_train)
pred_test  = xgb.predict(X_test)

print("No PCA XGBoost")
print("RMSE train:", np.sqrt(mean_squared_error(y_train, pred_train)))
print("RMSE test :", np.sqrt(mean_squared_error(y_test, pred_test)))
print("R2 train  :", r2_score(y_train, pred_train))
print("R2 test   :", r2_score(y_test, pred_test))
# Out:
# No PCA XGBoost
# RMSE train: 1.2690026943358075
# RMSE test : 2.156273833942175
# R2 train  : 0.9359130921498453
# R2 test   : 0.8109904084053688

# %%
# TRAIN results table
train_results = train_meta.copy()
train_results["popularity"] = y_train
train_results["prediction"] = pred_train

# TEST results table
test_results = test_meta.copy()
test_results["popularity"] = y_test
test_results["prediction"] = pred_test

# Convert pandas -> Spark
pred_train_spark = spark.createDataFrame(train_results)
pred_test_spark = spark.createDataFrame(test_results)

# %%
print("Top train examples by actual popularity")

pred_train_spark.select(
    "track_id",
    "track_name",
    "artist_name",
    "popularity",
    "prediction"
)\
.orderBy(F.desc("popularity"))\
.show(10, truncate=False)

print("Top test examples by actual popularity")

pred_test_spark.select(
    "track_id",
    "track_name",
    "artist_name",
    "popularity",
    "prediction"
)\
.orderBy(F.desc("popularity"))\
.show(10, truncate=False)
# Out:
# Top train examples by actual popularity
# +----------------------+------------------------------+--------------+----------+-----------------+
# |track_id              |track_name                    |artist_name   |popularity|prediction       |
# +----------------------+------------------------------+--------------+----------+-----------------+
# |5hnyJvgoWiQUYZttV4wXy6|Chasing Cars                  |Snow Patrol   |83        |81.42186737060547|
# |3MJ6lFNV12FSHAOzTzkwxz|Smile                         |Morgan Wallen |83        |82.34909057617188|
# |2gfn28JSINCJGLrUimmu0l|Cantada Boba - Ao Vivo        |Jorge & Mateus|80        |78.53498840332031|
# |6dbh2fgGhV5s8rxSOOsEMv|no tiene sentido              |Beéle         |74        |73.27948760986328|
# |7n5QRJlaXL5a3LCjOwsdcs|YEDA YUNG                     |YUNG DSA      |73        |71.93872833251953|
# |43rA71bccXFGD4C8GOpIlN|I Forgot That You Existed     |Taylor Swift  |71        |69.91299438476562|
# |13TtTCE6v8vwTSgWJPjwLl|girl you're taking home       |Ella Langley  |70        |69.31901550292969|
# |7sopDXkuzXtHt8AQpdBxmT|DONA DE MIM                   |Ana Castela   |70        |69.27580261230469|
# |1DpC4L3JjsGRW7y6eTHaMj|Ojos Tristes (with The Marías)|The Marías    |69        |65.62303924560547|
# |4M6wwQvRKBKV6DPLEjEeKJ|Left Eye                      |BigXthaPlug   |68        |67.26276397705078|
# +----------------------+------------------------------+--------------+----------+-----------------+
# only showing top 10 rows
#
# Top test examples by actual popularity
# +----------------------+----------------------------------+------------------+----------+------------------+
# |track_id              |track_name                        |artist_name       |popularity|prediction        |
# +----------------------+----------------------------------+------------------+----------+------------------+
# |6otePxalBK8AVa20xhZYVQ|MIENTRAS ME CURO DEL CORA         |KAROL G           |78        |67.22034454345703 |
# |2dXGQvRkJo5klX67yOSNYn|Sol solecito caliéntame un poquito|NULL              |66        |66.29541778564453 |
# |32rUiWgyd3Du6uJe0CbXR3|Fall Fast in Love                 |Rod Wave          |64        |51.5272102355957  |
# |5VKvDHouRJ4a8VNXrzTWnc|Dj Waley Babu (feat. Aastha Gill) |Badshah           |63        |41.09455108642578 |
# |0W7brFokN6QtGRNp32RCQP|Alone With You                    |Arz               |63        |65.92572021484375 |
# |7okAszmL6H3YM6mtX5TZYW|Skinny Little Missy               |Nickelback        |63        |53.78728103637695 |
# |0jxJyDR5XEsz3zBlRrd5GN|KEHLANI                           |Jala Brat         |62        |61.265380859375   |
# |4IHVD1YAzu4woX532t2XyL|DISNEYLANDIA                      |Gabito Ballesteros|62        |60.718082427978516|
# |13Ke2nWjtjlpI4UrUqzJSQ|Sleepy Brown 130 Hz - Seamless    |Jane Color        |62        |60.26530075073242 |
# |1SwZVVH9BnXtLRLi2cbFhw|Good day                          |IU                |61        |39.0783576965332  |
# +----------------------+----------------------------------+------------------+----------+------------------+
# only showing top 10 rows

# %% [markdown]
# The prediction table shows that the XGBoost model without PCA produces values that closely follow the true popularity scores. High-popularity songs tend to receive high predicted values, and the differences between actual and predicted values are generally small.
# This indicates that the model successfully captures the relationship between the input features and the target variable. The model is able to generalize well to unseen data, as demonstrated by similar prediction quality on the test set.
# Although the model slightly underestimates some higher values, the overall prediction accuracy is strong and consistent with the high R² score. This represents a significant improvement over the PCA-based model, which failed to capture meaningful patterns and produced consistently low predictions.

# %%
import matplotlib.pyplot as plt

plt.scatter(test_results["popularity"], test_results["prediction"], alpha=0.3)

plt.xlabel("Actual Popularity")
plt.ylabel("Predicted Popularity")
plt.title("Actual vs Predicted Popularity")

# Perfect line
plt.plot([0, 100], [0, 100], color='red')

plt.show()

# %% [markdown]
# The scatter plot of actual versus predicted popularity shows a strong positive relationship, indicating that the model successfully captures the overall trend in the data. Most points follow the diagonal direction, demonstrating that higher popularity values tend to receive higher predictions.
# However, the plot also reveals that the model slightly underestimates higher popularity values, as evidenced by points falling below the ideal diagonal line in the upper range. Additionally, the model tends to slightly overestimate very low popularity values.
# This behavior suggests that the model smooths predictions toward the mean, resulting in smaller errors overall but reduced sensitivity to extreme values. Despite this, the model performs well, as reflected by the strong R² (~0.81) and low RMSE (~2.16), representing a significant improvement over the PCA-based model
